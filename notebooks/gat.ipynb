# %%
import grid2op
import numpy as np
import torch
from grid2op.PlotGrid import PlotMatplot

# %%
env = grid2op.make("l2rpn_neurips_2020_track2_small")
action_space = env.action_space

# %% [markdown]
# We treat generators, loads and lines as graph nodes

# %%
env.current_env.current_obs.a.
# Out:
# array([ 73.35697  , 146.14485  , 250.21286  ,  45.08659  ,  50.106865 ,
#         41.742176 ,   5.290946 , 168.03557  , 150.80489  ,  72.03417  ,
#         93.84684  ,  77.14719  ,  52.36655  , 128.85667  ,  46.250492 ,
#        205.0971   ,  65.62249  ,  89.12509  ,  41.76137  ,  37.116085 ,
#         74.44535  , 267.57977  ,  88.99359  , 109.50264  ,  73.22251  ,
#         64.08296  ,  94.83825  ,  73.88519  ,  49.24525  , 191.57372  ,
#         75.009285 , 142.44348  , 127.92122  , 289.48746  ,  90.23399  ,
#        167.85773  , 130.39366  , 137.43564  , 112.68499  ,  86.14227  ,
#        144.01453  ,  49.73357  , 105.41219  ,  37.63961  ,  63.81904  ,
#         30.662788 , 101.161095 ,  16.709166 ,  49.001205 , 153.73634  ,
#         64.39078  ,  53.154934 ,  31.00333  ,   9.6995125,  37.898926 ,
#        103.427475 ,  84.245766 ,  43.169807 , 219.13203  ,  19.15088  ,
#         58.029564 ,  46.93845  ,  98.81392  , 396.00082  , 121.37293  ,
# ...
