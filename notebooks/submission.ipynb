# %% [markdown]
# ## Train

# %%
import os
from submission_utils import test_submission, prepare_submission
from IPython.core.display import display, HTML

# %%
# !PYTHONPATH=../src/ python ../src/train.py
# Out:
# Traceback (most recent call last):
#   File "../src/train.py", line 8, in <module>
#     from agent import BeUAgent
#   File "/home/alex/Projects/L2RPN/src/agent.py", line 1, in <module>
#     from agents.actor_critic_agents.sac_discrete import SACDiscrete
#   File "/home/alex/Projects/L2RPN/src/agents/actor_critic_agents/sac_discrete.py", line 6, in <module>
#     from ...agents.base_agent import BaseAgent
# ValueError: attempted relative import beyond top-level package

# %% [markdown]
# ## Prepare submission

# %%
submission_path = prepare_submission("../check_points/2020_09_16_14_23_26_episode_100/")

# %% [markdown]
# ## Test submission

# %%
test_submission(submission_path)
# Out:
# INFO: Basic check and creation of the zip file for the folder ../submissions/sub_2020_09_17_05_50_54
#
# INFO: No custom reward for the assessment of your agent will be used. If you want to use a custom reward when your agent is evaluated, make sure to export  "reward", which should be a class inheriting from grid2op.BaseReward in your module (done in __init__.py).
# INFO: No custom other_rewards for the assessment of your agent will be used. If you want to get information about other rewards when your agent is evaluated, make sure to export  "other_rewards" dictionnary in your module (you can do it in the __init__.py file)
# Your submission appear to be valid. For more test, we encourage you to run the appropriate notebook to do these unit testing.
# The zip file "/home/alex/Projects/L2RPN/notebooks/submission_20-09-17-05-51.zip" has been created with your submission in it.
#
# INFO: Checking the zip file can be unzipped.
#
#
# INFO: Checking content is valid
#
#
# ...

# %%
display(HTML(f"{submission_path}_res/results.html"))
# Out:
# <html><head></head><body>
# <div style='margin: 0 auto; width: 500px;'><p>Score 23.805</p><p>Duration 4.76</p></div><img src="data:image/png;base64,..."><br><img src="data:image/png;base64,..."><br></body></html>

# %%
## Results below are from do nothing agent, do not remove

# %%
# Out:
# <html><head></head><body>
# <div style='margin: 0 auto; width: 500px;'><p>Score 0.0</p><p>Duration 0.11</p></div><img src="data:image/png;base64,..."><br><img src="data:image/png;base64,..."><br></body></html>
